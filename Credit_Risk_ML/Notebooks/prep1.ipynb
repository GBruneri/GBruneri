# %%
# Bibliotécas utilizadas
import pandas as pd

# %%
# Import de dados e Path
loc_1 = r'/content/customer_data.csv'
loc_2 = r'/content/payment_data.csv'

# Criando o primeiro DF baseado nos clientes.
df_customer = pd.read_csv(loc_1)

df_customer.head()
# Out:
#    label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0      1  54982665      5  1245.5      3   77000.0      2     15      5
# 1      0  59004779      4  1277.0      1  113000.0      2      8     -1
# 2      0  58990862      7  1298.0      1  110000.0      2     11     -1
# 3      1  58995168      7  1335.5      1  151000.0      2     11      5
# 4      0  54987320      7     NaN      2   59000.0      2     11      5
#
#    fea_8  fea_9  fea_10      fea_11
# 0    109      5  151300  244.948974
# 1    100      3  341759  207.173840
# 2    101      5   72001    1.000000
# 3    110      3   60084    1.000000
# 4    108      4  450081  197.403141

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1125 entries, 0 to 1124
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   1125 non-null   int64
#  1   id      1125 non-null   int64
#  2   fea_1   1125 non-null   int64
#  3   fea_2   976 non-null    float64
#  4   fea_3   1125 non-null   int64
#  5   fea_4   1125 non-null   float64
#  6   fea_5   1125 non-null   int64
#  7   fea_6   1125 non-null   int64
#  8   fea_7   1125 non-null   int64
#  9   fea_8   1125 non-null   int64
#  10  fea_9   1125 non-null   int64
#  11  fea_10  1125 non-null   int64
#  12  fea_11  1125 non-null   float64
# dtypes: float64(3), int64(10)
# memory usage: 114.4 KB

# %%
print(f'Existem {df_customer.isna().sum().sum()} valores NaN no dataframe.')
print()
print(f'Existe {df_customer.duplicated().sum()} duplicatadas no dataframe')
# Out:
# Existem 149 valores NaN no dataframe.
#
# Existe 0 duplicatadas no dataframe

# %%
# Criando o segundo DF baseado nos pagamentos.
df_payment = pd.read_csv(loc_2)
df_payment.head()
# Out:
#          id  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  prod_code  \
# 0  58987402       0       0       0        0           1         10
# 1  58995151       0       0       0        0           1          5
# 2  58997200       0       0       0        0           2          5
# 3  54988608       0       0       0        0           3         10
# 4  54987763       0       0       0        0           2         10
#
#    prod_limit update_date  new_balance  highest_balance report_date
# 0     16500.0  04/12/2016          0.0              NaN         NaN
# 1         NaN  04/12/2016     588720.0         491100.0         NaN
# 2         NaN  04/12/2016     840000.0         700500.0  22/04/2016
# 3     37400.0  03/12/2016       8425.2           7520.0  25/04/2016
# 4         NaN  03/12/2016      15147.6              NaN  26/04/2016

# %%
df_payment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8250 entries, 0 to 8249
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               8250 non-null   int64
#  1   OVD_t1           8250 non-null   int64
#  2   OVD_t2           8250 non-null   int64
#  3   OVD_t3           8250 non-null   int64
#  4   OVD_sum          8250 non-null   int64
#  5   pay_normal       8250 non-null   int64
#  6   prod_code        8250 non-null   int64
#  7   prod_limit       2132 non-null   float64
#  8   update_date      8224 non-null   object
#  9   new_balance      8250 non-null   float64
#  10  highest_balance  7841 non-null   float64
#  11  report_date      7136 non-null   object
# dtypes: float64(3), int64(7), object(2)
# memory usage: 773.6+ KB

# %%
print(f'Existem {df_payment.isna().sum().sum()} valores NaN no dataframe.')
print()
print(f'Existe {df_payment.duplicated().sum()} duplicatas no dataframe')
# Out:
# Existem 7667 valores NaN no dataframe.
#
# Existe 91 duplicatas no dataframe

# %%
# Remover duplicatas do dataframe df_payment com base no ID do cliente
df_payment_unique = df_payment.drop_duplicates(keep='first')
# Concatenar os dataframes df_customer e df_payment_unique com base no ID do cliente
df_combined = pd.merge(df_customer, df_payment_unique, on='id', how='inner')

# Habilitando a visualização de todas as colunas.
pd.set_option('display.max_columns', 35 )

# Verificar o novo dataframe combinado
df_combined.head()
# Out:
#    label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0      1  54982665      5  1245.5      3   77000.0      2     15      5
# 1      1  54982665      5  1245.5      3   77000.0      2     15      5
# 2      1  54982665      5  1245.5      3   77000.0      2     15      5
# 3      1  54982665      5  1245.5      3   77000.0      2     15      5
# 4      0  59004779      4  1277.0      1  113000.0      2      8     -1
#
#    fea_8  fea_9  fea_10      fea_11  OVD_t1  OVD_t2  OVD_t3  OVD_sum  \
# 0    109      5  151300  244.948974       0       0       0        0
# 1    109      5  151300  244.948974       0       0       0        0
# 2    109      5  151300  244.948974       0       0       0        0
# 3    109      5  151300  244.948974       0       2      26    11906
# 4    100      3  341759  207.173840       0       0       0        0
#
#    pay_normal  prod_code  prod_limit update_date  new_balance  \
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Criando um caminho para salvar o dataframe.
salva = r'/content/drive/MyDrive/Code/Myrep/Fraude1/Datasets/dataframe.csv'

# Salve o DataFrame
df_combined.to_csv(salva, index=False)
